# %%
import requests

key="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJINWNwUGpicUpFdFdKMjdTSlI5UFNNZUY1N09xQ1lRVWhjejJCa3UyTFNQa01qVVB5VUVTVWhNZFNOZnVhQnZRRmMtZFhYc0ZvUWFDSjVEVCIsImlhdCI6MTcxMDg0Njc4MX0.yzj8qQ2eq28LoKSp2KAOb05MmDSooirEwVB9LCtoDjg"

def gov_request(id_set, params=None):
    url = "https://dados.gov.br/dados/api/publico/conjuntos-dados/" + id_set
    response = requests.get(url, params=params, headers = {"chave-api-dados-abertos" : key})
    
    if response.headers.get('content-type') != 'application/json':
        return print(response.headers.get('content-type'))

    return response.json()

# %% [markdown]
# ## API Request

# %% [markdown]
# É possivel retirar dados das seguintes fontes:
#
# https://dados.gov.br/dados/api/publico/conjuntos-dados/ 'nome do conjunto' \
# https://dados.gov.br/dados/api/temas/ 'nome do tema'

# %%
url = "https://dados.gov.br/dados/api/reuso"#publico/conjuntos-dados"
response = requests.get(url, params=params, headers = {"chave-api-dados-abertos" : key})
print(response.headers.get('content-type'))
response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 url = "https://dados.gov.br/dados/api/reuso"#publico/conjuntos-dados"
# ----> 2 response = requests.get(url, params=params, headers = {"chave-api-dados-abertos" : key})
#       3 print(response.headers.get('content-type'))
#       4 response.json()
#
# NameError: name 'params' is not defined

# %%
#key_p = "d1a18f481606ca1797e32ef53c29c63a"
#key_m = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiJ2eVlId0hJSnpCSUY1S1B4cTlHWl9wQVBmUjdFMzhoXzhYNTZDbEZWT2RXMDFRRjg0YVpsRVVZZ05zdlVwcHkybHFuSmVpVzNwUXpSbEpkXyIsImlhdCI6MTc1Njc2MDAzMH0.iL3b2e0AGBPFhzHsiomMeOrCZUi4BEexty873Sy4RwQ"
#key_h  ="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJINWNwUGpicUpFdFdKMjdTSlI5UFNNZUY1N09xQ1lRVWhjejJCa3UyTFNQa01qVVB5VUVTVWhNZFNOZnVhQnZRRmMtZFhYc0ZvUWFDSjVEVCIsImlhdCI6MTcxMDg0Njc4MX0.yzj8qQ2eq28LoKSp2KAOb05MmDSooirEwVB9LCtoDjg"

# %%
url = "https://dados.gov.br/dados/api/publico/conjuntos-dados/"

# %%
reload()
id_conjunto = "bolsa-familia"

params = {
    "ano": 2025,  # Exemplo de filtro por ano
    "cidade": -1,
    "pagina": 1   # Página inicial
}

rq1 = gov_request(id_conjunto, params)

# %%
rq1
# Out:
# {'areaTecnicaResponsavel': 'Secretaria de Avaliação, Gestão da Informação e Cadastro Único - SAGICAD',
#  'emailAreaTecnicaResponsavel': 'dgi.sagicad@mds.gov.br',
#  'id': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#  'titulo': 'Bolsa Família',
#  'nome': 'bolsa-familia',
#  'organizacao': 'ministerio-do-desenvolvimento-e-assistencia-social-familia-e-combate-a-fome',
#  'descricao': 'O  **Bolsa Família** é um programa de transferência direta de renda, direcionado às famílias em situação de pobreza e de extrema pobreza em todo o País, de modo que consigam superar a situação de vulnerabilidade e pobreza.\nTem como principal objetivo combater a fome, a pobreza e promover a segurança alimentar e nutricional, retirando as famílias da vulnerabilidade socieconômica por meio da transferência de renda; Além disso,  através das condicionalidades,  reforçar o acesso aos direitos básicos e aos serviços de saúde, educação, segurança alimentar a assistência social.\n\n**Neste conjunto de dados temos as seguintes variáveis:**\n\nA partir de março de  2023:\n*  **ibge:** código ibge do município\n* **anomes:** ano e mês de referência\n* **qtd_familias_beneficiarias_bolsa_familia_s:** Quantidade de famílias beneficiárias do Programa Bolsa Família\n* **valor_repassado_bolsa_familia_s:** Valor repassado para pagamento de benefícios do Programa Bolsa Família\n* **pbf_vlr_medio_benef_f:** Valor médio dos benefícios pagos do Programa Bolsa Família\n\nDe 2004 a 2021:\n* **ibge:** código ibge do município\n* **anomes:** ano e mês de referência\n* **qtd_familias_beneficiarias_bolsa_familia:** Quantidade de famílias beneficiárias do Programa Bolsa Família\n* **valor_repassado_bolsa_familia:** Valor repassado para pagamento de benefícios do Programa Bolsa Família\n\nEsse conjunto de dados informa a quantidade de famílias beneficiárias e o valor repassado através da folha de pagamento do Bolsa Família, assim como o município e ano/mês de referência. \n\nPara saber mais informações sobre os dados do programa no período de Nov/2021 a Fev/2023, consulte os indicadores do [Programa Auxílio Brasil (PAB)](https://dados.gov.br/dados/conjuntos-dados/auxlio-brasil---mi-social), clique no link:\n[https://dados.gov.br/dados/conjuntos-dados/auxlio-brasil---mi-social](https://dados.gov.br/dados/conjuntos-dados/auxlio-brasil---mi-social)\n\n**Painel de Análise dos Dados**:\n[https://aplicacoes.mds.gov.br/sagi-paineis/analise_dados_abertos/](http://aplicacoes.mds.gov.br/sagi-paineis/analise_dados_abertos/)\n\n__Soluções utilizadas para abertura deste conjunto de dados:__\n\n__VIS DATA:__  é a ferramenta informacional sucessora da Matriz de Informações Sociais concebida em 2005. O VIS DATA se utiliza do conceito de base de dados para armazenar e gerir diversos indicadores e variáveis.\n\nAcesse o [VIS DATA](https://aplicacoes.mds.gov.br/sagi/vis/data3/data-explorer.php)\n\n__Documenta Wiki:__ é uma ferramenta online que busca concentrar a documentação e as informações mais detalhadas (os metadados) dos programs e dos indicadores de monitoramento.\n\nAcesse o [Documenta Wiki - Bolsa Família](https://wiki-sagi.cidadania.gov.br/en/home/DS/NBF)',
#  'licenca': 'cc-by',
#  'periodicidade': 'MENSAL',
#  'temas': [{'name': 'administracao', 'title': 'Administração'},
#   {'name': 'protecao-social', 'title': 'Proteção Social'}],
#  'tags': [{'id': 'cfc77b82-95c3-4c9e-928b-af777f8b99c3',
#    'name': 'MI Social',
#    'display_name': None},
#   {'id': '39b525db-6e7e-4812-a255-1f829b6ff121',
#    'name': 'MISocial',
#    'display_name': None},
#   {'id': 'bf891517-bf46-484e-a7d4-567856f68be2',
#    'name': 'Matriz de informação social',
#    'display_name': None},
#   {'id': '20cf1b7e-df3f-428e-9bae-1c9bc1cb512c',
#    'name': 'PBF',
#    'display_name': None},
#   {'id': '69bc2009-0e4f-4692-9a1f-dcf8f1cb2810',
#    'name': 'benefício',
#    'display_name': None},
#   {'id': 'c47aaeaa-43c1-46ad-9e97-f74306a80153',
#    'name': 'bolsa família',
#    'display_name': None},
#   {'id': '57b282c4-b220-44ef-a7ea-7636adbf8706',
#    'name': 'misocial',
#    'display_name': None},
#   {'id': '58b02f5b-591c-4285-bb9c-ccd50e283a85',
#    'name': 'programa bolsa família',
#    'display_name': None},
#   {'id': '481d4ad5-6e68-49ee-a912-549e87a30166',
#    'name': 'quantidade de famílias',
#    'display_name': None},
#   {'id': '2809e20d-0faa-4adf-9b70-0992af8a59df',
#    'name': 'vis data',
#    'display_name': None}],
#  'coberturaTemporalInicio': None,
#  'coberturaTemporalFim': None,
#  'coberturaEspacial': None,
#  'valorCoberturaEspacial': None,
#  'granularidadeEspacial': None,
#  'versao': '1.1',
#  'atualizacaoVersao': False,
#  'visibilidade': 'PUBLICA',
#  'descontinuado': False,
#  'dataDescontinuacao': None,
#  'reuso': False,
#  'recursos': [{'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '14/02/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fq=anomes_s:2025*&fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=csv',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF em 2025',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2025 - Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '0fc0c220-e0f4-4553-9807-8da4c418ac51'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '14/02/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fq=anomes_s:2025*&fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=json&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF em 2025',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2025 - Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'ad6aef02-f207-4363-8ffa-0b088fae0cd0'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202501%20TO%20202504%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2025.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2025 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'b87b6794-d77a-485c-8f5f-fce1103f2b48'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202505%20TO%20202508%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2025.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2025 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'e2ad9d31-7b6b-4e4f-b98c-57b9ad6fc51f'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '22/04/2024',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fq=anomes_s:2024*&fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=csv',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF em 2024',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2024 - Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'fb2af163-5beb-46d7-84a5-7d6595ed565e'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '22/04/2024',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fq=anomes_s:2024*&fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=json',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF em 2024',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2024 - Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '680f8673-1bc6-46d7-b625-26055e68475a'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202401%20TO%20202404%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2024.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2024 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '68d78fb1-9227-4011-9aef-3051e76f23ac'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202405%20TO%20202408%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2024.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2024 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'b4ce0290-38fd-44e5-9a81-c06f6a6a3b75'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202409%20TO%20202412%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 3º Quadrimestre de 2024.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2024 (3º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '3dd9f1c0-9c0b-4f1a-bb90-c09ef3f2fb97'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '20/03/2023',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fq=anomes_s:2023*&fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=csv',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF em 2023',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2023 - Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '3c3c5de3-4687-4a8f-8637-5a3a6531ea8d'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '20/03/2023',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fq=anomes_s:2023*&fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=json',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF em 2023',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2023 - Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '7c218093-ed21-4452-866a-6c9dcd413daa'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202301%20TO%20202304%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2023.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2023 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'd6222e51-08a2-4abc-9454-77b82979581d'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202305%20TO%20202308%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2023.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2023 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '75fc8ccb-a114-4a7a-87b7-07fc45f38990'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202309%20TO%20202312%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 3º Quadrimestre de 2023.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2023 (3º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'd9b9eb73-8abf-4356-a821-5f1118debeec'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '15/09/2021',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2021*&fq=tipo_s:mes_mu&wt=csv&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF em 2021',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2021 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': '229f6961-2987-4caa-b6ba-174609a6a58d'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '06/10/2022',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2021*&fq=tipo_s:mes_mu&wt=json&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF em 2021',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2021 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': 'f1ba8b00-a136-4033-a5f0-7215f249b25b'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202101%20TO%20202104%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2021.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2021 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '6014c975-69cf-4fb3-adc2-00eee2905661'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202105%20TO%20202108%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2021.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2021 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'f329010e-82ab-4f3c-ae43-e4ce4e0208fc'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202109%20TO%20202112%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 3º Quadrimestre de 2021.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2021 (3º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '25360d79-2ff9-4a50-8c4a-cb2601d06729'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '11/03/2020',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2020*&fq=tipo_s:mes_mu&wt=csv&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2020 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': '38e68862-9d69-4bf5-b0a5-34ebcfd5e5a6'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '11/03/2020',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?q=*&fq=anomes_s:2020*&fq=tipo_s:mes_mu&wt=json&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2020 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': '1d36b4c4-b0e6-4977-a7a0-7773097789f5'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202001%20TO%20202004%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2020.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2020 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '296df594-abb0-4ee8-84ed-81a500bb5215'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202005%20TO%20202008%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2020.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2020 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '6012ba09-c41c-4698-936d-aa4e80c879ab'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b202009%20TO%20202012%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 3º Quadrimestre de 2020.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2020 (3º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '0c3baa8c-3581-47ce-97b5-06b65c1fdc19'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '11/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2019*&fq=tipo_s:mes_mu&wt=csv&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2019 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': 'ff147c2e-46c2-4c55-ace7-e16dab6e0d35'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '15/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2019*&fq=tipo_s:mes_mu&wt=json&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2019 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': 'f44aee38-d862-451b-a0e1-8104819398ff'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201901%20TO%20201904%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2019.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2019 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'c3cce1db-0792-4fde-9c0d-db44c41cb2fe'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201905%20TO%20201908%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2019.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2019 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '97f2cce3-c310-4821-afa5-88679344808c'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201909%20TO%20201912%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 3º Quadrimestre de 2019.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2019 (3º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'b41ab397-03ae-4a79-b54b-ad834ec39c70'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '11/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2018*&fq=tipo_s:mes_mu&wt=csv&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2018 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': 'f293bc40-f5a7-471d-9f72-4cb2459ffdfa'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '15/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2018*&fq=tipo_s:mes_mu&wt=json&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2018 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': '6682a806-77b8-405b-a756-2c172fbfa488'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201801%20TO%20201804%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2018.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2018 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'b1e8bb86-9984-4857-91a5-bfaca8acfced'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201805%20TO%20201808%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2018.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2018 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'cd9ecd7f-8101-4b43-8ba6-ab393b9f0836'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201809%20TO%20201812%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 3º Quadrimestre de 2018.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2018 (3º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '15e9f1e5-9553-4ff9-941c-543e69bd1228'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '08/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2017*&fq=tipo_s:mes_mu&wt=csv&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2017 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': '5452685c-03a9-49d2-847b-e889c4aa46d3'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '15/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2017*&fq=tipo_s:mes_mu&wt=json&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2017 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': '46acd8dd-3193-4aab-84f2-63e1498c2ebe'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201701%20TO%20201704%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2017.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2017 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '48357679-9cba-4bc7-bebe-72f04a7dbaf2'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201705%20TO%20201708%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2017.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2017 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '7272d598-d891-4df9-8711-19188fa581be'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201709%20TO%20201712%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 3º Quadrimestre de 2017.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2017 (3º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '50b205d3-5243-49d7-bb2c-7001f2512c85'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '08/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2016*&fq=tipo_s:mes_mu&wt=csv&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'CSV',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2016 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': 'ff9c5f25-4e80-4923-a7d6-b099fd22199c'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '15/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2016*&fq=tipo_s:mes_mu&wt=json&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'quantidadeDownloads': None,
#    'tipo': None,
#    'numOrdem': None,
#    'formato': 'JSON',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2016 - Quantidade de Famílias Beneficiárias e Valor Repassado do PBF',
#    'id': '9ce657f4-ca38-4af9-9227-ecd02115750d'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201601%20TO%20201604%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 1º Quadrimestre de 2016.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'xlm',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': ' 2016 (1º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '865388e0-4642-4c3b-9ea9-5f557a5f1516'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201605%20TO%20201608%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 2º Quadrimestre de 2016.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'xlm',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2016 (2º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': '05d0220c-631d-488f-b7dd-b8c9566674bd'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '19/08/2025',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial/?fl=codigo_ibge%2Canomes_s%2Cqtd_familias_beneficiarias_bolsa_familia_s%2Cvalor_repassado_bolsa_familia_s%2Cpbf_vlr_medio_benef_f&fq=valor_repassado_bolsa_familia_s%3A*&q=*%3A*&rows=100000&sort=anomes_s%20desc%2C%20codigo_ibge%20asc&wt=xml&fq=anomes:%5b201609%20TO%20201612%5d&omitHeader=true',
#    'nomeArquivo': None,
#    'descricao': 'Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF no formato xml no 3º Quadrimestre de 2016.',
#    'quantidadeDownloads': None,
#    'tipo': 'DADOS',
#    'numOrdem': None,
#    'formato': 'XML',
#    'idConjuntoDados': '7ed7c95a-ec15-45ed-a4cd-1c07fe70d45d',
#    'titulo': '2016 (3º Quadrimestre)-  Quantidade De Famílias Beneficiárias, Valor Repassado e Valor Médio dos benefícios pagos do PBF',
#    'id': 'c83167d3-e8fa-4dbc-945c-8046a4eee166'},
#   {'tamanho': 0,
#    'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#    'dataCatalogacao': '08/12/2017',
#    'link': 'https://aplicacoes.mds.gov.br/sagi/servicos/misocial?fq=anomes_s:2015*&fq=tipo_s:mes_mu&wt=csv&q=*&fl=ibge:codigo_ibge,anomes:anomes_s,qtd_familias_beneficiarias_bolsa_familia,valor_repassado_bolsa_familia&rows=10000000&sort=anomes_s%20asc,%20codigo_ibge%20asc',
#    'nomeArquivo': None,
# ...
#       'dataUltimaAtualizacaoArquivo': '20/09/2023'},
#      {'id': '40af89ac-bee5-483a-ad03-c294b6677a8b',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Fevereiro/2022',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202202',
#       'descricao': 'Fevereiro - 2022',
#       'tipo': 'DADOS',
#       'formato': 'ZIP',
#       'dataCriacao': '2023-07-13T21:34:17.775766',
#       'tamanho': 0,
#       'nomeArquivo': None,
#       'quantidadeDownloads': None,
#       'numOrdem': None,
#       'dataCatalogacao': '13/07/2023',
#       'dataUltimaAtualizacaoArquivo': '20/09/2023'},
#      {'id': '81dd73de-e5b1-4298-a5a1-b4f3748b7fa6',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Janeiro/2022',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202201',
#       'descricao': 'Janeiro - 2022',
#       'tipo': 'DADOS',
#       'formato': 'ZIP',
#       'dataCriacao': '2023-07-13T21:32:40.992251',
#       'tamanho': 0,
#       'nomeArquivo': None,
#       'quantidadeDownloads': None,
#       'numOrdem': None,
#       'dataCatalogacao': '13/07/2023',
#       'dataUltimaAtualizacaoArquivo': '20/09/2023'},
#      {'id': '169dfa02-80ff-481a-b93e-b3995926fa76',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Dezembro/2021',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202112',
#       'descricao': 'Dezembro - 2021',
#       'tipo': 'DADOS',
#       'formato': 'ZIP',
#       'dataCriacao': '2023-07-13T18:41:53.043798',
#       'tamanho': 0,
#       'nomeArquivo': None,
#       'quantidadeDownloads': None,
#       'numOrdem': None,
#       'dataCatalogacao': '13/07/2023',
#       'dataUltimaAtualizacaoArquivo': '20/09/2023'},
#      {'id': 'f9acb48c-97a2-4ba1-907e-8e9a9d6e8f03',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Novembro/2021',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202111',
#       'descricao': 'Novembro - 2021',
#       'tipo': 'DADOS',
#       'formato': 'ZIP',
#       'dataCriacao': '2023-07-13T18:30:28.554164',
#       'tamanho': 0,
#       'nomeArquivo': None,
#       'quantidadeDownloads': None,
#       'numOrdem': None,
#       'dataCatalogacao': '13/07/2023',
#       'dataUltimaAtualizacaoArquivo': '20/09/2023'}],
#     'dataUltimaAtualizacaoMetadados': '15/03/2025 12:27:07',
#     'dataUltimaAtualizacaoArquivo': '13/06/2025 15:20:31',
#     'dataCatalogacao': '13/07/2023 18:30:28',
#     'atualizado': 'Atualização não verificável'},
#    'conjuntoDadosApiView': {'areaTecnicaResponsavel': 'SAGICAD - Secretaria de Avaliação, Gestão da Informação e Cadastro Único',
#     'emailAreaTecnicaResponsavel': 'dgi.sagicad@mds.gov.br',
#     'id': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#     'titulo': 'Auxílio Brasil - Pagamentos (Descontinuado)',
#     'nome': 'auxilio-brasil---pagamentos',
#     'organizacao': 'ministerio-do-desenvolvimento-e-assistencia-social-familia-e-combate-a-fome',
#     'descricao': 'O Auxílio Brasil integra em um só programa com várias políticas públicas de assistência social, saúde, educação, emprego e renda. O programa social de transferência direta e indireta de renda é destinado às famílias em situação de pobreza e de extrema pobreza em todo o país. Além de garantir uma renda básica a essas famílias, o programa busca simplificar a cesta de benefícios e estimular a emancipação dessas famílias para que alcancem autonomia e superem situações de vulnerabilidade social.\n\nDados disponibilizados no Portal da Transparência pelo MDS.\n\n__Obs__: Para consultar meses/anos diferentes na relação apresentada, basta efetuar a substituição do ano/mês no final do arquivo.   \n__ex__:  \nwww.portaltransparencia.gov.br/download-de-dados/auxilio-brasil/__202112__\n\nO conjunto __Auxílio Brasil - Pagamentos__ foi __descontinuado__. Por favor consulte a sessão __Conjunto de Dados Similares__.',
#     'licenca': 'cc-by',
#     'periodicidade': 'MENSAL',
#     'temas': [{'name': 'administracao', 'title': 'Administração'},
#      {'name': 'protecao-social', 'title': 'Proteção Social'}],
#     'tags': [{'id': '9015f922-d58c-4ce5-9806-643858539897',
#       'name': 'auxílio Brasil',
#       'display_name': None},
#      {'id': '8167d4e9-539e-4ef0-8bc3-cdd57636b96f',
#       'name': 'mds',
#       'display_name': None}],
#     'coberturaTemporalInicio': '01/11/2021',
#     'coberturaTemporalFim': '28/02/2023',
#     'coberturaEspacial': None,
#     'valorCoberturaEspacial': None,
#     'granularidadeEspacial': None,
#     'versao': '1.0',
#     'atualizacaoVersao': False,
#     'visibilidade': 'PUBLICA',
#     'descontinuado': True,
#     'dataDescontinuacao': None,
#     'reuso': False,
#     'recursos': [{'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '13/06/2025',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaldatransparencia.gov.br/pagina-interna/605516-dicionario-de-dados-auxilio-brasil-pagamentos',
#       'nomeArquivo': None,
#       'descricao': 'Dicionário de Dados do Auxílio Brasil - Pagamentos',
#       'quantidadeDownloads': None,
#       'tipo': 'DICIONARIO_DE_DADOS',
#       'numOrdem': None,
#       'formato': 'HTML',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Dicionário de Dados - Auxílio Brasil - Pagamentos',
#       'id': '054c9e3d-66ac-4e23-bd4b-fc9eac984663'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202302',
#       'nomeArquivo': None,
#       'descricao': 'Fevereiro - 2023',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Fevereiro/2023',
#       'id': '3d8c6e6d-903f-4d83-bac8-bca54ada23b3'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202301',
#       'nomeArquivo': None,
#       'descricao': 'Janeiro - 2023',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Janeiro/2023',
#       'id': 'aa03ce95-e7e5-49a5-9332-a550bad7e5b8'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202212',
#       'nomeArquivo': None,
#       'descricao': 'Dezembro - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Dezembro/2022',
#       'id': '29623da2-e733-4f4e-b02b-ce2348ecae35'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202211',
#       'nomeArquivo': None,
#       'descricao': 'Novembro - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Novembro/2022',
#       'id': 'c485cf18-f87b-46d2-99da-260c0a046f1b'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202210',
#       'nomeArquivo': None,
#       'descricao': 'Outubro - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Outubro/2022',
#       'id': '779f343d-fb9a-4430-a1c3-6223e7066646'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202209',
#       'nomeArquivo': None,
#       'descricao': 'Setembro - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Setembro/2022',
#       'id': 'e27e3dc7-11ec-4d80-b34c-7e9885cbfbba'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202208',
#       'nomeArquivo': None,
#       'descricao': 'Agosto - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Agosto/2022',
#       'id': '32a3826a-1c83-4baf-bc46-0489e97736a8'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202207',
#       'nomeArquivo': None,
#       'descricao': 'Julho - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Julho/2022',
#       'id': '4b99f544-5d39-4645-bd07-02b76d17dc98'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202206',
#       'nomeArquivo': None,
#       'descricao': 'Junho - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Junho/2022',
#       'id': '4c1e3a7e-e51a-4dd4-9599-a17371bebfb8'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202205',
#       'nomeArquivo': None,
#       'descricao': 'Maio - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Maio/2022',
#       'id': '6ec24bfc-b9bb-4adf-9e9c-64296a58d040'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202204',
#       'nomeArquivo': None,
#       'descricao': 'Abril - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Abril/2022',
#       'id': '0b393c20-40e8-4635-8936-63fb38aa77e8'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202203',
#       'nomeArquivo': None,
#       'descricao': 'Março - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Março/2022',
#       'id': 'e3100a38-e00a-493e-9324-9a1128872d49'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202202',
#       'nomeArquivo': None,
#       'descricao': 'Fevereiro - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Fevereiro/2022',
#       'id': '40af89ac-bee5-483a-ad03-c294b6677a8b'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202201',
#       'nomeArquivo': None,
#       'descricao': 'Janeiro - 2022',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Janeiro/2022',
#       'id': '81dd73de-e5b1-4298-a5a1-b4f3748b7fa6'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202112',
#       'nomeArquivo': None,
#       'descricao': 'Dezembro - 2021',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Dezembro/2021',
#       'id': '169dfa02-80ff-481a-b93e-b3995926fa76'},
#      {'tamanho': 0,
#       'dataUltimaAtualizacaoArquivo': '20/09/2023',
#       'dataCatalogacao': '13/07/2023',
#       'link': 'https://portaltransparencia.gov.br/download-de-dados/auxilio-brasil/202111',
#       'nomeArquivo': None,
#       'descricao': 'Novembro - 2021',
#       'quantidadeDownloads': None,
#       'tipo': 'DADOS',
#       'numOrdem': None,
#       'formato': 'ZIP',
#       'idConjuntoDados': '4f3df7bd-6e4f-4a1f-9914-ca59de5fda54',
#       'titulo': 'Pagamentos - Novembro/2021',
#       'id': 'f9acb48c-97a2-4ba1-907e-8e9a9d6e8f03'}],
#     'dataUltimaAtualizacaoMetadados': '15/03/2025 12:27:07',
#     'dataUltimaAtualizacaoArquivo': '13/06/2025 15:20:31',
#     'dataCatalogacao': '13/07/2023 18:30:28',
#     'atualizado': 'Atualização não verificável',
#     'dadosRacaEtnia': False,
#     'dadosGenero': False},
#    'inacessivel': False,
#    'visibilidade': 'Público',
#    'dataUltimaAtualizacaoDados': '2025-06-13T15:20:31',
#    'owner_org': 'c6da56e5-166d-46b7-9c37-4af22fa081ff',
#    'license_id': 'cc-by',
#    'license_title': 'Creative Commons Atribuição',
#    'metadata_created': '13/07/2023 18:30:28',
#    'metadata_modified': '01/09/2025 23:22:29',
#    'maintainer_email': 'dgi.sagicad@mds.gov.br',
#    'private': False,
#    'num_resources': 17,
#    'markdownNotes': '<p>O Auxílio Brasil integra em um só programa com várias políticas públicas de assistência social, saúde, educação, emprego e renda. O programa social de transferência direta e indireta de renda é destinado às famílias em situação de pobreza e de extrema pobreza em todo o país. Além de garantir uma renda básica a essas famílias, o programa busca simplificar a cesta de benefícios e estimular a emancipação dessas famílias para que alcancem autonomia e superem situações de vulnerabilidade social.</p>\n<p>Dados disponibilizados no Portal da Transparência pelo MDS.</p>\n<p><strong>Obs</strong>: Para consultar meses/anos diferentes na relação apresentada, basta efetuar a substituição do ano/mês no final do arquivo.<br />\n<strong>ex</strong>:<br />\nwww.portaltransparencia.gov.br/download-de-dados/auxilio-brasil/<strong>202112</strong></p>\n<p>O conjunto <strong>Auxílio Brasil - Pagamentos</strong> foi <strong>descontinuado</strong>. Por favor consulte a sessão <strong>Conjunto de Dados Similares</strong>.</p>\n'}],
#  'dataUltimaAtualizacaoMetadados': '21/08/2025 11:34:32',
#  'dataUltimaAtualizacaoArquivo': 'Indisponível',
#  'dataCatalogacao': '30/11/2017 20:20:09',
#  'atualizado': 'Atualização não verificável',
#  'dadosRacaEtnia': False,
#  'dadosGenero': False}
