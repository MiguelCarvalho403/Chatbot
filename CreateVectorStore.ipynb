# %% [markdown]
# # Create VectorStore

# %%
import requests
key="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJINWNwUGpicUpFdFdKMjdTSlI5UFNNZUY1N09xQ1lRVWhjejJCa3UyTFNQa01qVVB5VUVTVWhNZFNOZnVhQnZRRmMtZFhYc0ZvUWFDSjVEVCIsImlhdCI6MTcxMDg0Njc4MX0.yzj8qQ2eq28LoKSp2KAOb05MmDSooirEwVB9LCtoDjg"
def gov_request(id_set, params=None):
    url = "https://dados.gov.br/dados/api/publico/conjuntos-dados/" + id_set
    response = requests.get(url, params=params, headers = {"chave-api-dados-abertos" : key})
    
    if response.headers.get('content-type') != 'application/json':
        return print(response.headers.get('content-type'))

    return response.json()

# %%
import json
def read_json(file_path):
    with open(file_path, "r") as json_file:
        data = json.load(json_file)
    return data

# %% [markdown]
# ### Carrega catalogo

# %%
rq = read_json("saves/catalogo_9990conjuntodeDados.json")

# %% [markdown]
# ### Carrega metadados

# %%
rq1 = read_json("saves/metados_9990.json")

# %% [markdown]
# ### Salva objetos Document

# %%
import pickle

# %%
for doc in documents:
    with open('documents', 'ab') as arquivo_binario:
        pickle.dump(doc, arquivo_binario)

# %% [markdown]
# ### Carrega Objeto Document

# %%
import pickle

# %%
with open("documents", "rb") as arquivo_binario:
  while True:
    try:
        documents.append(pickle.load(arquivo_binario))
    except EOFError:
        break

# %% [markdown]
# ## Estruturação dos metadados

# %% [markdown]
# ### Documents Catalogo

# %%
documents = []

[documents.append(

    {
    "id": doc['id'],
    "title": doc['title'],
    "nome": doc['nome'],
    'descricao': rq1[doc['id']]["descricao"],
    "catalogacao": doc['catalogacao'],
    "nomeOrganizacao": doc['nomeOrganizacao'],
    "ultimaAlteracaoMetadados": doc['ultimaAlteracaoMetadados'],
    "ultimaAtualizacaoDados": doc['ultimaAtualizacaoDados'],
    "isAtualizado": doc['isAtualizado'],
    }

) for doc in rq]

documents[0]
# Out:
# {'id': '3fc794a6-4217-4038-9b9d-b0ac7335efc3',
#  'title': '"Patrimônio Genético Nacional" que foram envolvidas em pesquisas realizadas na UFAM por ano',
#  'nome': 'patrimonio-genetico-nacional-que-foram-envolvidas-em-pesquisas-realizadas-na-ufam-por-ano',
#  'descricao': 'Relação das espécies do "Patrimônio Genético Nacional" que foram envolvidas em pesquisas realizadas na UFAM por ano',
#  'catalogacao': '08/02/2025 13:42:46',
#  'nomeOrganizacao': 'fundacao-universidade-do-amazonas',
#  'ultimaAlteracaoMetadados': '07/02/2025 19:59:50',
#  'ultimaAtualizacaoDados': '07/02/2025 19:59:50',
#  'isAtualizado': False}

# %% [markdown]
# ### Schema catalogo

# %%
[
  {
    "id": "string",
    "title": "string",
    "nome": "string",
    "catalogacao": "string",
    "nomeOrganizacao": "string",
    "ultimaAlteracaoMetadados": "string",
    "ultimaAtualizacaoDados": "string",
    "isAtualizado": True
  }
]
# Out:
# [{'id': 'string',
#   'title': 'string',
#   'nome': 'string',
#   'catalogacao': 'string',
#   'nomeOrganizacao': 'string',
#   'ultimaAlteracaoMetadados': 'string',
#   'ultimaAtualizacaoDados': 'string',
#   'isAtualizado': True}]

# %% [markdown]
# ### Documents Recursos

# %% [markdown]
# ### schema Detalhamento de conjunto

# %%
{
  "id": "string",
  "titulo": "string",
  "nome": "string",
  "organizacao": "string",
  "descricao": "string",
  "licenca": "string",
  "responsavel": "string",
  "emailResponsavel": "string",
  "periodicidade": "INVALIDO",
  "temas": [
    {
      "name": "string",
      "title": "string"
    }
  ],
  "tags": [
    {
      "id": "string",
      "name": "string",
      "display_name": "string"
    }
  ],
  "coberturaTemporalInicio": "2025-10-06",
  "coberturaTemporalFim": "2025-10-06",
  "coberturaEspacial": "INVALIDO",
  "valorCoberturaEspacial": "string",
  "granularidadeEspacial": "INVALIDO",
  "versao": "string",
  "atualizacaoVersao": true,
  "visibilidade": "INVALIDO",
  "descontinuado": true,
  "dataDescontinuacao": "2025-10-06",
  "reuso": true,
  "recursos": [
    {
      "dataUltimaAtualizacaoArquivo": "string",
      "dataCatalogacao": "string",
      "quantidadeDownloads": 0,
      "nomeArquivo": "string",
      "link": "string",
      "idConjuntoDados": "string",
      "titulo": "string",
      "formato": "string",
      "tipo": "INVALIDO",
      "numOrdem": 0,
      "descricao": "string",
      "tamanho": 0,
      "id": "string"
    }
  ],
  "dataUltimaAtualizacaoMetadados": "string",
  "dataUltimaAtualizacaoArquivo": "string",
  "dataCatalogacao": "string",
  "atualizado": "string",
  "dadosRacaEtnia": true,
  "dadosGenero": true,
  "ods": [
    0
  ],
  "observanciaLegal": "string",
  "dadosAbertos": "string",
  "selo": "string",
  "origemCadastro": "string"
}

# %% [markdown]
# ## Criação da VectorStore

# %% [markdown]
# ### Carregando modelo de Embedding

# %% [markdown]
# Será utilizado LangChain com HuggingFace

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
'''O objeto embeddingd neste notebook será utilizado para criar a VectorStore, portanto será otimizado para criação de embeddings de documentos
e não para criação de embeddings de queries.'''
matryoshka_dim = 1024 # Dimensão do modelo de embedding

embedd_model_name="Qwen/Qwen3-Embedding-0.6B" # Modelo de embedding, permite dimensão customizada de 1024

model_kwargs = {"device": "cpu", 'truncate_dim':matryoshka_dim}
encode_kwargs = {"normalize_embeddings": False}

# Conecta com LangChain
embeddings = HuggingFaceEmbeddings(model_name=embedd_model_name, 
                                   model_kwargs=model_kwargs,
                                   encode_kwargs=encode_kwargs)

# %% [markdown]
# ### Vector DataBase

# %% [markdown]
# Será utilizado Qdrant

# %%
from qdrant_client import models, QdrantClient
from sentence_transformers import SentenceTransformer

# %%
encoder = SentenceTransformer("Qwen/Qwen3-Embedding-0.6B", device='cpu')

# %%
#client = QdrantClient(":memory:") # Carrega vectorstore na memoria

# %%
clientd = QdrantClient(path="saves/VScatalogo") # Carrega vectorstore em disco

# %% [markdown]
# Cria objeto client na memoria

# %%
'''Vale testar duas abordagens sugeridas na documentação do Qdrant:
1. Criar a coleção com quantização escalar (Scalar Quantization) para reduzir o tamanho do armazenamento.
2. Criar a coleção on-disk, para diminuir o uso da memoria RAM.

quantization_config=models.ScalarQuantization(
    scalar=models.ScalarQuantizationConfig(
        type=models.ScalarType.INT8,
        quantile=0.99,
        always_ram=True,
    )

'''


clientd.create_collection(
    collection_name="catalogo", # nome da coleção
    vectors_config=models.VectorParams(
        size=encoder.get_sentence_embedding_dimension(),  # Vector size is defined by used model
        distance=models.Distance.COSINE, # Metrica de similaridade
    ),
)

# %%
documents[1000]
# Out:
# {'id': '42ccd54e-80b8-48d8-b48d-e3519227d464',
#  'title': 'Avaliação de desempenho dos cursos de graduação',
#  'nome': 'avaliao-de-desempenho-dos-cursos-de-graduao',
#  'catalogacao': '30/04/2025 12:00:34',
#  'nomeOrganizacao': 'fundacao-universidade-federal-do-pampa',
#  'ultimaAlteracaoMetadados': '30/04/2025 09:00:34',
#  'ultimaAtualizacaoDados': 'Indisponível',
#  'isAtualizado': False}

# %%
import torch
torch.cuda.empty_cache()

# %%
# Carrega documents para objeto client

'''

coletion: Armazena conjunto de points
PointsStructure:  Armazena ids, vetores(embeddings) e payload
payload: metada sobre os vetores

vetor: recebe embedding do modelo, no caso abaixo será utilizado description como conteudo a ser buscado


No for abaixo, o ideal é fazer em batches, para evitar estouro de memoria RAM/GPU
'''

batches = []
num_batches = 50

for idx, doc in enumerate(documents):
    if idx % (len(documents)//num_batches) == 0:
        print(f'Processando batch {idx // (len(documents)//num_batches) + 1} de {num_batches}')
        torch.cuda.empty_cache() # Limpa memoria GPU

    rq1_doc = rq1.get(doc['id'])
    if rq1_doc is not None and rq1_doc.get("descricao") is not None:
        point = models.PointStruct(
            id=idx,
            vector=encoder.encode(rq1_doc["descricao"]).tolist(),
            payload=doc
        )

        batches.append(point)
# Out:
# Processando batch 1 de 50
# Processando batch 2 de 50
# Processando batch 3 de 50
# Processando batch 4 de 50
# Processando batch 5 de 50
# Processando batch 6 de 50
# Processando batch 7 de 50
# Processando batch 8 de 50
# Processando batch 9 de 50
# Processando batch 10 de 50
# Processando batch 11 de 50
# Processando batch 12 de 50
# Processando batch 13 de 50
# Processando batch 14 de 50
# Processando batch 15 de 50
# Processando batch 16 de 50
# Processando batch 17 de 50
# Processando batch 18 de 50
# Processando batch 19 de 50
# Processando batch 20 de 50
# Processando batch 21 de 50
# Processando batch 22 de 50
# Processando batch 23 de 50
# Processando batch 24 de 50
# Processando batch 25 de 50
# Processando batch 26 de 50
# Processando batch 27 de 50
# Processando batch 28 de 50
# Processando batch 29 de 50
# Processando batch 30 de 50
# Processando batch 31 de 50
# Processando batch 32 de 50
# Processando batch 33 de 50
# Processando batch 34 de 50
# Processando batch 35 de 50
# Processando batch 36 de 50
# Processando batch 37 de 50
# Processando batch 38 de 50
# Processando batch 39 de 50
# Processando batch 40 de 50
# Processando batch 41 de 50
# Processando batch 42 de 50
# Processando batch 43 de 50
# Processando batch 44 de 50
# Processando batch 45 de 50
# Processando batch 46 de 50
# Processando batch 47 de 50
# Processando batch 48 de 50
# Processando batch 49 de 50
# Processando batch 50 de 50
# Processando batch 51 de 50

# %%
'''
coletion_name: Nome da coleção a ser utilizada
points: lista de pointStructures a serem inseridos
batch_size: Tamanho do batch para inserção
'''
clientd.upload_points(
    collection_name="catalogo",
    points=batches,
    batch_size=1000
)

# %%
from googletrans import Translator

translator = Translator()
result = await translator.translate('quero dados de criminalidade', src='pt', dest='en')
print(result.text)
# Out:
# I want crime data

# %%
'''

query_points: metodo para fazer buscas sobre coleção(vectorstore)


Testes preliminares:
    
    Utilizar query em inglês pode trazer resultados mais relevantes, mesmo para buscas em português.
    
    Descrever o papel do modelo na instrução (Instrução:) melhora significativamente a relevância dos resultados.

Futuros caminhos de pesquisa:

    Estudar tasks mais elaboradas

    Talvez utlizar tasks dinamicas, ou seja, descrever o papel do modelo com base na query do usuário.

    Utlizar na vectorestore dados como titulo, nome e descrição para melhorar a relevância dos resultados, algumas descrições não possuem
    nome do nome do catalogo o que leva a uma busca menos precisa.

    Encontrar um meio de filtrar dados do catalogo por Datas, tags, formatos, temas(saúde, educação, segurança pública)...

    Talves dispensar o catalogo e fazer uma vector store unica ou fazer duas vectorstores separadas?

        Caso haja duas vectorstores, como conectar ambas? 
        A vectorestore dentro do catalogo pode ser feita no momento da query?
'''

tasks = ["Você é um motor de busca, devolva dados mais relevantes",
         "Você é um motor de busca, devolva dados mais relevantes com base na busca"]

queries = ['quero dados de criminalidade',
           "Dados do bolsa família",
           "Quero informsções sobre infecções hospitalares"]

query_pt = f"Instrução: {tasks[0]} Query: {queries[2]}"
query_en = await translator.translate(query_pt, src='pt', dest='en')

query = query_en.text

print("Query em português:", query_pt)
print("Query utilizada:", query)

hits = clientd.query_points(
    collection_name="catalogo",
    query=encoder.encode(query).tolist(),
    limit=200,
).points

for hit in hits:
    print("score:", hit.score)
    print("Titulo: ",hit.payload.get('title'))
    print("Nome: ", hit.payload.get('nome'))
    #print("Descrição: ", hit.payload.get('descricao'))
    print('\n')
# Out:
# Query em português: Instrução: Você é um motor de busca, devolva dados mais relevantes Query: Quero informsções sobre infecções hospitalares
# Query utilizada: Instruction: You are a search engine, return more relevant query data: I want information about hospital infections
# score: 0.7260159389201888
# Titulo:  04. Infecção Hospitalar
# Nome:  04-infeccao-hospitalar
#
#
# score: 0.6281829066734866
# Titulo:  Infecção Hospitalar
# Nome:  infeccao-hospitalar
#
#
# score: 0.6096969897809625
# Titulo:  9. Taxa de Infecção Relacionada à Assistência em Saúde
# Nome:  9-taxa-de-infeccao-relacionada-a-assistencia-em-saude
#
#
# score: 0.5922331356830233
# Titulo:  Infecção nas unidades de internação HUWC
# Nome:  infeccao-nas-unidades-de-internacao-huwc
#
#
# score: 0.5740322910513684
# Titulo:  Infecção Hospitalar HUWC
# Nome:  infeccao-hospitalar-huwc
#
#
# score: 0.531889507153
# Titulo:  Internações hospitalares por unidade de internação
# Nome:  internacoes-hospitalares-por-unidade-de-internacao
#
#
# score: 0.5293398391360595
# Titulo:  Internação hospitalar na UTI - HU-Univasf
# Nome:  internacao-hospitalar-na-uti-hu-univasf
#
#
# score: 0.5293398391360595
# Titulo:  Internação hospitalar na UTI
# Nome:  internacao-hospitalar-na-uti
#
#
# score: 0.5293398391360595
# Titulo:  Internação hospitalar na UTI
# Nome:  internacao-hospitalar-na-uti-hupes
#
#
# score: 0.5293398391360595
# Titulo:  Internação hospitalar na UTI Humap-UFMS
# Nome:  internacao-hospitalar-na-uti-humap-ufms
#
#
# score: 0.5293398391360595
# Titulo:  16. Internação hospitalar na UTI
# Nome:  internacao-hospitalar-na-uti-do-hujm
#
#
# score: 0.5235513590525251
# Titulo:  Mortalidade na internação hospitalar HC-UFTM
# Nome:  mortalidade-na-internacao-hospitalar-hc-uftm
#
#
# score: 0.5175556542128523
# Titulo:  Mortalidade hospitalar HUWC
# Nome:  mortalidade-hospitalar-huwc
#
#
# score: 0.5096850373245708
# Titulo:  Mortalidade hospitalar MEAC
# Nome:  mortalidade-hospitalar-meac
#
#
# score: 0.506427353325763
# Titulo:  Mortalidade da internação hospitalar
# Nome:  mortalidade-da-internacao-hospitalar-hupes
#
#
# score: 0.506427353325763
# Titulo:  Mortalidade da internação hospitalar
# Nome:  mortalidade-da-internacao-hospitalar
#
#
# score: 0.506427353325763
# Titulo:  Mortalidade da internação hospitalar - HU-Univasf
# Nome:  mortalidade-da-internacao-hospitalar-hu-univasf
#
#
# score: 0.5049546289323764
# Titulo:  Painel do Setor de Hotelaria Hospitalar - HU-UFSCar
# Nome:  painel-do-setor-de-hotelaria-hospitalar---hu-ufscar
#
#
# score: 0.5019422541315448
# Titulo:  Internação por leito HUL-UFS
# Nome:  internacao-por-leito-hul-ufs
#
#
# score: 0.5007151059786558
# Titulo:  Alta hospitalar HUWC
# Nome:  alta-hospitalar-huwc
#
#
# score: 0.5007151059786558
# Titulo:  Alta hospitalar MEAC
# Nome:  alta-hospitalar-meac
#
#
# score: 0.4996700853322614
# Titulo:  Internação hospitalar por leito Humap-UFMS
# Nome:  internacao-hospitalar-por-leito-humap-ufms
#
#
# score: 0.4990251852791035
# Titulo:  Internação hospitalar na UTI HC-UFTM
# Nome:  internacao-hospitalar-na-uti-hc-uftm
#
#
# score: 0.4960534384199668
# Titulo:  Ocupação de leito Hospitalar
# Nome:  ocupao-de-leito-hospitalar
#
#
# score: 0.4950254498519829
# Titulo:  Internação Hospitalar HUL-UFS
# Nome:  internacao-hospitalar-hul-ufs
#
#
# score: 0.4939998985097488
# Titulo:  4. Internação Hospitalar
# Nome:  4-internacao-hospitalar
#
#
# score: 0.4924344804670585
# Titulo:  Mortalidade da internação  hospitalar - Hospital Universitário de Brasília (HUB-UnB)
# Nome:  mortalidade-da-internacao--hospitalar---hospital-universitario-de-brasilia-hub-unb
#
#
# score: 0.48988645231112526
# Titulo:  Informações cadastrais dos Hospitais
# Nome:  informacoes-cadastrais-hospitais
#
#
# score: 0.4893360707664726
# Titulo:  Internação em UTI - Hospital Universitário de Brasília (HUB-UnB)
# Nome:  internao-em-uti---hospital-universitrio-de-braslia-hub-unb
# Nome:  internao-hospitalar-por-leito---hospital-universitrio-de-braslia-hub-unb
#
#
# score: 0.4491201022136799
# Titulo:  Internações em Leitos Clínicos - HU-UFSCar
# Nome:  internacoes-em-leitos-clinicos---hu-ufscar
#
#
# score: 0.44811692855207635
# Titulo:  Manutenções realizadas de equipamentos médico hospitalares
# Nome:  manutencoes-realizadas-de-equipamentos-medico-hospitalares
#
#
# score: 0.4474789071437809
# Titulo:  Internação em UTI Adulto
# Nome:  internao-em-uti-adulto
#
#
# score: 0.4458043467615519
# Titulo:  Documentos para internação hospitalar
# Nome:  documentos-para-internacao-hospitalar-
#
#
# score: 0.4440579395631397
# Titulo:  Receitas recebidas
# Nome:  receitas-recebidas
#
#
# score: 0.4430873110044881
# Titulo:  Internações Hospitalares Realizadas
# Nome:  hc-ufmg-internacoes-realizadas
#
#
# score: 0.4399700978356647
# Titulo:  Mortalidade da internação hospitalar na UCI HDT-UFT
# Nome:  mortalidade-da-internacao-hospitalar-na-uci-hdt-uft
#
#
# score: 0.4377227797019624
# Titulo:  Pacientes internados/dia MEAC
# Nome:  pacientes-internadosdia-meac
#
#
# score: 0.4376330090097609
# Titulo:  Internação hospitalar por leito na UCI HDT-UFT
# Nome:  internacao-hospitalar-por-leito-na-uci-hdt-uft
#
#
# score: 0.43661785557236193
# Titulo:  Internação Hospitalar por Leito Husm-UFSM
# Nome:  internacao-hospitalar-por-leito-husm-ufsm
#
#
# score: 0.43639535896772685
# Titulo:  Internação Hospitalar Husm-UFSM
# Nome:  internacao-hospitalar-husm-ufsm
#
#
# score: 0.4359002488253857
# Titulo:  COMISSÕES
# Nome:  comisses-hujb-
#
#
# score: 0.43474393245302895
# Titulo:  Internação hospitalar por leito nas UTIs
# Nome:  taxa-de-ocupacao-de-leitos-nas-utis
#
#
# score: 0.43018144893029087
# Titulo:  Mortalidade na internação hospitalar na UTI - HU-Univasf
# Nome:  mortalidade-na-internacao-hospitalar-na-uti-hu-univasf
#
#
# score: 0.43018144893029087
# Titulo:  Mortalidade da internação hospitalar na UTI
# Nome:  mortalidade-da-internacao-hospitalar-na-uti
#
#
# score: 0.43018144893029087
# Titulo:  Mortalidade da internação hospitalar na UTI Humap-UFMS
# Nome:  mortalidade-da-internacao-hospitalar-na-uti-humap-ufms
#
#
# score: 0.43018144893029087
# Titulo:  Mortalidade da internação hospitalar na UTI
# Nome:  mortalidade-da-internacao-hospitalar-na-uti-hupes
#
#
# score: 0.4266851456450943
# Titulo:  INDICADORES IJF 2024
# Nome:  indicadores-2024
#
#
# score: 0.42517047666904406
# Titulo:  Atendimento em Cirurgias - HU-UFSCar
# Nome:  atendimento-em-cirurgias---hu-ufscar
#
#
# score: 0.4235996525361174
# Titulo:  Atendimento na internação da Equipe Multiprofissional MEAC
# Nome:  atendimento-na-internacao-da-equipe-multiprofissional-meac
#
#
# score: 0.422698785964735
# Titulo:  Grupo Diagnósticos Relacionados DRG
# Nome:  grupo_diagnosticos_relacionados_drg
#
#
# score: 0.4165478928867474
# Titulo:  Processamento de Roupas
# Nome:  processamento-de-roupas
#
#
# score: 0.41575263832447096
# Titulo:  Reabordagem Cirúrgica
# Nome:  reabordagem-cirurgica
#
#
# score: 0.41483193237564275
# Titulo:  Mortalidade da Internação Hospitalar na UTI Husm-UFSM
# Nome:  mortalidade-da-internacao-hospitalar-na-uti-husm-ufsm
#
#
# score: 0.4147265162379431
# Titulo:  Nº de transfusão de sangue e componentes irradiados
# Nome:  n-de-transfusoes-de-sangue-e-componentes-irradiados
#
#
# score: 0.4146695996721844
# Titulo:  COMITÊS
# Nome:  comits-hujb-
#
#
# score: 0.4146382444624235
# Titulo:  Leitos para internação  por mil habitantes
# Nome:  cgeo_vw_razao_leitos_1000_hab
#
#
# score: 0.41454835702493653
# Titulo:  Procedimentos Hospitalares por UF
# Nome:  procedimentos-hospitalares-por-uf
#
#
# score: 0.41447710780742
# Titulo:  Nome e quantidade de materiais esterilizados solicitados pelas unidades e enviados pela UPME
# Nome:  nome-e-quantidade-de-materiais-esterilizados-solicitados-pelas-unidades-e-enviados-pela-upme
#
#
# score: 0.41344829721531257
# Titulo:  Internação hospitalar - HU-Univasf
# Nome:  internacao-hospitalar-hu-univasf
#
#
# score: 0.41344829721531257
# Titulo:  Internação hospitalar Humap-UFMS
# Nome:  internacao-hospitalar-humap-ufms
#
#
# score: 0.41344829721531257
# Titulo:  Internação hospitalar
# Nome:  internacao-hospitalar
#
#
# score: 0.41344829721531257
# Titulo:  15. Internação hospitalar
# Nome:  internacao-hospitalar-do-hujm
#
#
# score: 0.41344829721531257
# Titulo:  Internação hospitalar
# Nome:  internacao-hospitalar-hupes
#
#
# score: 0.4115229125945175
# Titulo:  INTERNAÇÃO
# Nome:  internao
#
#
# score: 0.41089945974762465
# Titulo:  AIH - Dados das Autorizações de Internação Hospitalar
# Nome:  aih
#
#
# score: 0.41045871502557923
# Titulo:  Produtos e Prestadores Hospitalares
# Nome:  produtos-e-prestadores-hospitalares
#
#
# score: 0.41016638101688263
# Titulo:  Pacientes Internados
# Nome:  numero-de-pacientes-internados-por-especialidade
#
#
# score: 0.40986234458579657
# Titulo:  ESPECIALIDADES
# Nome:  especialidades
#
#
# score: 0.40768473410289585
# Titulo:  ESPECIALIDADES
# Nome:  relao-das-especialidades-encontradas-no-hujb-
#
#
# score: 0.4075133279398381
# Titulo:  Lista de  Contratos  firmados
# Nome:  lista-de--contratos--firmados
#
#
# score: 0.40665093694248555
# Titulo:  Indicadores de manutenção de Equipamentos Médico Hospitalares ativos
# Nome:  indicadores-de-manuteno-de-equipamentos-mdico-hospitalares-ativos
#
#
# score: 0.40479764606985513
# Titulo:  Registro de Ocupação Hospitalar COVID-19
# Nome:  registro-de-ocupacao-hospitalar-covid-19
#
#
# score: 0.4034222204187855
# Titulo:  Hospitais e Leitos
# Nome:  hospitais-e-leitos
#
#
# score: 0.40315397553717663
# Titulo:  Indicadores de Gestão do SIF
# Nome:  indicadores-de-gestao-do-sif-
#
#
# score: 0.3536666498168085
# Titulo:  Atendimento de Laboratorio de Análises Clínicas Realizados Husm-UFSM
# Nome:  atendimento-de-laboratorio-de-analises-clinicas-realizados-husm-ufsm
#
#
# score: 0.3536124836168629
# Titulo:  Quantidade de materiais desinfectados e esterilizados  na UPME
# Nome:  quantidade-de-materiais-desinfectados-e-esterilizados--na-upme
#
#
# score: 0.353469686014458
# Titulo:  Nº de exames de parasitologia, por mês
# Nome:  n-de-exames-de-parasitologia-por-mes
#
#
# score: 0.35335746943844404
# Titulo:  Empregados CLT
# Nome:  relacao-de-empregados-ebserh-regime-clt-ativos-no-hc-por-cargo-

# %%
'''

query_filter: permite adicionar filtros a busca

'''

hits = clientd.query_points(
    collection_name="my_books",
    query=encoder.encode("alien invasion").tolist(),
    query_filter=models.Filter(
        must=[models.FieldCondition(key="year", range=models.Range(gte=2000))] # gte greater than or equal?
    ),
    limit=1,
).points

for hit in hits:
    print(hit.payload, "score:", hit.score)
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 7
#       1 '''
#       2
#       3 query_filter: permite adicionar filtros a busca
#       4
#       5 '''
# ----> 7 hits = clientd.query_points(
#       8     collection_name="my_books",
#       9     query=encoder.encode("alien invasion").tolist(),
#      10     query_filter=models.Filter(
#      11         must=[models.FieldCondition(key="year", range=models.Range(gte=2000))] # gte greater than or equal?
#      12     ),
#      13     limit=1,
#      14 ).points
#      16 for hit in hits:
#      17     print(hit.payload, "score:", hit.score)
#
# File ~/miniforge3/envs/DataScience/lib/python3.13/site-packages/qdrant_client/qdrant_client.py:593, in QdrantClient.query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     578         else:
#     579             prefetch = (
#     580                 next(
#     581                     iter(
#    (...)    590                 else None
#     591             )
# --> 593 return self._client.query_points(
#     594     collection_name=collection_name,
#     595     query=query,
#     596     prefetch=prefetch,
#     597     query_filter=query_filter,
#     598     search_params=search_params,
#     599     limit=limit,
#     600     offset=offset,
#     601     with_payload=with_payload,
#     602     with_vectors=with_vectors,
#     603     score_threshold=score_threshold,
#     604     using=using,
#     605     lookup_from=lookup_from,
#     606     consistency=consistency,
#     607     shard_key_selector=shard_key_selector,
#     608     timeout=timeout,
#     609     **kwargs,
#     610 )
#
# File ~/miniforge3/envs/DataScience/lib/python3.13/site-packages/qdrant_client/local/qdrant_local.py:455, in QdrantLocal.query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, **kwargs)
#     439 def query_points(
#     440     self,
#     441     collection_name: str,
#    (...)    453     **kwargs: Any,
#     454 ) -> types.QueryResponse:
# --> 455     collection = self._get_collection(collection_name)
#     457     if query is not None:
#     458         query, mentioned_ids = self._resolve_query_input(
#     459             collection_name, query, using, lookup_from
#     460         )
#
# File ~/miniforge3/envs/DataScience/lib/python3.13/site-packages/qdrant_client/local/qdrant_local.py:172, in QdrantLocal._get_collection(self, collection_name)
#     170 if collection_name in self.aliases:
#     171     return self.collections[self.aliases[collection_name]]
# --> 172 raise ValueError(f"Collection {collection_name} not found")
#
# ValueError: Collection my_books not found
